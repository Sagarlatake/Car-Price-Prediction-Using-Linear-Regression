# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('scrap_price.csv')

# %%
data.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# Show all columns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible         rwd          front       88.6      168.8      64.1
# 1  convertible         rwd          front       88.6      168.8      64.1
# 2    hatchback         rwd          front       94.5      171.2      65.5
# 3        sedan         fwd          front       99.8      176.6      66.2
# 4        sedan         4wd          front       99.4      176.6      66.4
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# ID                  205 non-null int64
# symboling           205 non-null int64
# name                205 non-null object
# fueltypes           205 non-null object
# aspiration          205 non-null object
# doornumbers         205 non-null object
# carbody             205 non-null object
# drivewheels         205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# ...

# %%
data.isna().sum()
# Out:
# ID                  0
# symboling           0
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.nunique()
# Out:
# ID                  205
# symboling             6
# name                147
# fueltypes             2
# aspiration            2
# doornumbers           2
# carbody               5
# drivewheels           3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
data.head(1)
# Out:
#    ID  symboling                name fueltypes aspiration doornumbers  \
# 0   1          3  alfa-romero giulia       gas        std         two
#
#        carbody drivewheels enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible         rwd          front       88.6      168.8      64.1
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
#
#    highwaympg    price
# 0          27  13495.0

# %%
col_numeric = data.select_dtypes(include='number')
col_numeric
# Out:
#       ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0      1          3       88.6      168.8      64.1       48.8        2548
# 1      2          3       88.6      168.8      64.1       48.8        2548
# 2      3          1       94.5      171.2      65.5       52.4        2823
# 3      4          2       99.8      176.6      66.2       54.3        2337
# 4      5          2       99.4      176.6      66.4       54.3        2824
# 5      6          2       99.8      177.3      66.3       53.1        2507
# 6      7          1      105.8      192.7      71.4       55.7        2844
# 7      8          1      105.8      192.7      71.4       55.7        2954
# 8      9          1      105.8      192.7      71.4       55.9        3086
# 9     10          0       99.5      178.2      67.9       52.0        3053
# 10    11          2      101.2      176.8      64.8       54.3        2395
# ...

# %%
col_object = data.select_dtypes(include='object')
col_object
# Out:
#                                 name fueltypes aspiration doornumbers  \
# 0                 alfa-romero giulia       gas        std         two
# 1                alfa-romero stelvio       gas        std         two
# 2           alfa-romero Quadrifoglio       gas        std         two
# 3                        audi 100 ls       gas        std        four
# 4                         audi 100ls       gas        std        four
# 5                           audi fox       gas        std         two
# 6                         audi 100ls       gas        std        four
# 7                          audi 5000       gas        std        four
# 8                          audi 4000       gas      turbo        four
# 9                audi 5000s (diesel)       gas      turbo         two
# 10                          bmw 320i       gas        std         two
# 11                          bmw 320i       gas        std        four
# ...

# %%
# select column names in a list

col_obj_name = col_object.columns
col_obj_name
# Out:
# Index(['name', 'fueltypes', 'aspiration', 'doornumbers', 'carbody',
#        'drivewheels', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
# Only ID column is not required, so we can drop the column

# %%
data.drop(columns='ID', inplace=True)
data.head()
# Out:
#    symboling                      name fueltypes aspiration doornumbers  \
# 0          3        alfa-romero giulia       gas        std         two
# 1          3       alfa-romero stelvio       gas        std         two
# 2          1  alfa-romero Quadrifoglio       gas        std         two
# 3          2               audi 100 ls       gas        std        four
# 4          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible         rwd          front       88.6      168.8      64.1
# 1  convertible         rwd          front       88.6      168.8      64.1
# 2    hatchback         rwd          front       94.5      171.2      65.5
# 3        sedan         fwd          front       99.8      176.6      66.2
# 4        sedan         4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# ...

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in col_obj_name:
    data[col] = LabelEncoder().fit_transform(data[col])
    
data.head()
# Out:
#    symboling  name  fueltypes  aspiration  doornumbers  carbody  drivewheels  \
# 0          3     2          1           0            1        0            2
# 1          3     3          1           0            1        0            2
# 2          1     1          1           0            1        2            2
# 3          2     4          1           0            0        3            1
# 4          2     5          1           0            0        3            0
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0               0       88.6      168.8      64.1       48.8        2548
# 1               0       88.6      168.8      64.1       48.8        2548
# 2               0       94.5      171.2      65.5       52.4        2823
# 3               0       99.8      176.6      66.2       54.3        2337
# 4               0       99.4      176.6      66.4       54.3        2824
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
# symboling           205 non-null int64
# name                205 non-null int64
# fueltypes           205 non-null int64
# aspiration          205 non-null int64
# doornumbers         205 non-null int64
# carbody             205 non-null int64
# drivewheels         205 non-null int64
# enginelocation      205 non-null int64
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null int64
# cylindernumber      205 non-null int64
# enginesize          205 non-null int64
# fuelsystem          205 non-null int64
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# horsepower          205 non-null int64
# ...

# %%
data.describe()
# Out:
#         symboling        name   fueltypes  aspiration  doornumbers  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean     0.834146   77.209756    0.902439    0.180488     0.439024
# std      1.245307   41.014583    0.297446    0.385535     0.497483
# min     -2.000000    0.000000    0.000000    0.000000     0.000000
# 25%      0.000000   44.000000    1.000000    0.000000     0.000000
# 50%      1.000000   80.000000    1.000000    0.000000     0.000000
# 75%      2.000000  115.000000    1.000000    0.000000     1.000000
# max      3.000000  146.000000    1.000000    1.000000     1.000000
#
#           carbody  drivewheels  enginelocation   wheelbase   carlength  \
# count  205.000000   205.000000      205.000000  205.000000  205.000000
# mean     2.614634     1.326829        0.014634   98.756585  174.049268
# std      0.859081     0.556171        0.120377    6.021776   12.337289
# min      0.000000     0.000000        0.000000   86.600000  141.100000
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.corr()
# Out:
#                   symboling      name  fueltypes  aspiration  doornumbers  \
# symboling          1.000000 -0.107095   0.194311   -0.059866     0.664073
# name              -0.107095  1.000000  -0.069435    0.019914    -0.171745
# fueltypes          0.194311 -0.069435   1.000000   -0.401397     0.191491
# aspiration        -0.059866  0.019914  -0.401397    1.000000    -0.031792
# doornumbers        0.664073 -0.171745   0.191491   -0.031792     1.000000
# carbody           -0.596135  0.099691  -0.147853    0.063028    -0.680358
# drivewheels       -0.041671 -0.016129  -0.132257    0.066465     0.098954
# enginelocation     0.212471  0.055968   0.040070   -0.057191     0.137757
# wheelbase         -0.531954  0.014550  -0.308346    0.257611    -0.447357
# carlength         -0.357612  0.053016  -0.212679    0.234539    -0.398568
# carwidth          -0.232919 -0.075349  -0.233880    0.300567    -0.207168
# carheight         -0.541038  0.201900  -0.284631    0.087311    -0.552208
# ...

# %%
363.

# %%
df_corr = pd.DataFrame(data.corr())
df_corr
# Out:
#                   symboling      name  fueltypes  aspiration  doornumbers  \
# symboling          1.000000 -0.107095   0.194311   -0.059866     0.664073
# name              -0.107095  1.000000  -0.069435    0.019914    -0.171745
# fueltypes          0.194311 -0.069435   1.000000   -0.401397     0.191491
# aspiration        -0.059866  0.019914  -0.401397    1.000000    -0.031792
# doornumbers        0.664073 -0.171745   0.191491   -0.031792     1.000000
# carbody           -0.596135  0.099691  -0.147853    0.063028    -0.680358
# drivewheels       -0.041671 -0.016129  -0.132257    0.066465     0.098954
# enginelocation     0.212471  0.055968   0.040070   -0.057191     0.137757
# wheelbase         -0.531954  0.014550  -0.308346    0.257611    -0.447357
# carlength         -0.357612  0.053016  -0.212679    0.234539    -0.398568
# carwidth          -0.232919 -0.075349  -0.233880    0.300567    -0.207168
# carheight         -0.541038  0.201900  -0.284631    0.087311    -0.552208
# ...

# %%
# get y filtered

df_corr_y = df_corr['price']
df_corr_y
# Out:
# symboling          -0.079978
# name               -0.231439
# fueltypes          -0.105679
# aspiration          0.177926
# doornumbers        -0.031835
# carbody            -0.083976
# drivewheels         0.577992
# enginelocation      0.324973
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# carheight           0.119336
# curbweight          0.835305
# enginetype          0.049171
# cylindernumber     -0.027628
# enginesize          0.874145
# fuelsystem          0.526823
# boreratio           0.553173
# stroke              0.079443
# compressionratio    0.067984
# horsepower          0.808139
# peakrpm            -0.085267
# citympg            -0.685751
# highwaympg         -0.697599
# price               1.000000
# Name: price, dtype: float64

# %%
df_corr_y = pd.DataFrame(df_corr_y)
df_corr_y.reset_index(inplace=True)
df_corr_y
# Out:
#                index     price
# 0          symboling -0.079978
# 1               name -0.231439
# 2          fueltypes -0.105679
# 3         aspiration  0.177926
# 4        doornumbers -0.031835
# 5            carbody -0.083976
# 6        drivewheels  0.577992
# 7     enginelocation  0.324973
# 8          wheelbase  0.577816
# 9          carlength  0.682920
# 10          carwidth  0.759325
# 11         carheight  0.119336
# 12        curbweight  0.835305
# 13        enginetype  0.049171
# 14    cylindernumber -0.027628
# 15        enginesize  0.874145
# 16        fuelsystem  0.526823
# 17         boreratio  0.553173
# 18            stroke  0.079443
# 19  compressionratio  0.067984
# 20        horsepower  0.808139
# 21           peakrpm -0.085267
# 22           citympg -0.685751
# 23        highwaympg -0.697599
# 24             price  1.000000

# %%
df_corr_y.rename(columns={'index': 'col_name'}, inplace=True)
df_corr_y.head()
# Out:
#       col_name     price
# 0    symboling -0.079978
# 1         name -0.231439
# 2    fueltypes -0.105679
# 3   aspiration  0.177926
# 4  doornumbers -0.031835

# %%
# select required column correkllation greater than 0.5
selected_col = []
for r in df_corr_y.iterrows():
    
    if np.abs(r[1]['price'])>0.5:
        print(r[1]['price'])
        selected_col.append(r[1]['col_name'])
# Out:
# 0.5779915312861982
# 0.57781559829215
# 0.6829200156779612
# 0.7593252997415122
# 0.8353048793372965
# 0.8741448025245113
# 0.5268229602111608
# 0.5531732367984439
# 0.8081388225362213
# -0.6857513360270401
# -0.6975990916465568
# 1.0

# %%
# selected columns for prediction are       
selected_col
# Out:
# ['drivewheels',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'curbweight',
#  'enginesize',
#  'fuelsystem',
#  'boreratio',
#  'horsepower',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
data_final = data[selected_col]
data_final.head()
# Out:
#    drivewheels  wheelbase  carlength  carwidth  curbweight  enginesize  \
# 0            2       88.6      168.8      64.1        2548         130
# 1            2       88.6      168.8      64.1        2548         130
# 2            2       94.5      171.2      65.5        2823         152
# 3            1       99.8      176.6      66.2        2337         109
# 4            0       99.4      176.6      66.4        2824         136
#
#    fuelsystem  boreratio  horsepower  citympg  highwaympg    price
# 0           5       3.47         111       21          27  13495.0
# 1           5       3.47         111       21          27  16500.0
# 2           5       2.68         154       19          26  16500.0
# 3           5       3.19         102       24          30  13950.0
# 4           5       3.19         115       18          22  17450.0

# %%
x = data_final.drop(columns=['price'])
y = data_final['price']

print(x.shape)
print(y.shape)
# Out:
# (205, 11)
# (205,)

# %% [markdown]
# # data splitting

# %%
 from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2)

# %%
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (164, 11)
# (164,)
# (41, 11)
# (41,)

# %% [markdown]
# ### Build Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([ 2.34580271e+03,  5.49114851e+01, -3.47914845e+01,  6.11336745e+02,
#         1.25073666e+00,  8.72065596e+01, -3.16841063e+02, -1.25113152e+03,
#         5.56256595e+01,  2.09314375e+00, -2.18606350e+01])

# %%
lr.intercept_
# Out:
# -43808.431326967635

# %%
pred = lr.predict(xtest)
pred = pd.DataFrame(pred, columns=['price'])
pred
# Out:
#            price
# 0    9534.689272
# 1   11112.379504
# 2    9165.816029
# 3   17238.565351
# 4    9490.913489
# 5   16761.229257
# 6    6505.977248
# 7    7731.367324
# 8    7550.351818
# 9   13926.411776
# 10   7028.754976
# 11   9799.906212
# 12   8679.775167
# 13  22968.873587
# 14  16348.775082
# 15  11386.735627
# 16   6339.137169
# 17   6345.336698
# 18  19483.402742
# 19  11679.897424
# 20  13413.084062
# 21  11868.905054
# 22  20671.365931
# 23   8766.178199
# 24   3983.663569
# 25   6245.428791
# 26   8946.698137
# 27  16883.660801
# 28  13288.479612
# 29  11601.101014
# 30   9082.051252
# 31  14612.030946
# 32   9802.923366
# 33  15897.612508
# 34   8668.658768
# 35  16746.079768
# 36  18983.903663
# 37   6932.883276
# 38  10720.364825
# 39   7400.505863
# 40  15160.157126

# %% [markdown]
# ## Calculate Error

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(ytest,pred)
mae = mean_absolute_error(ytest, pred)
r2 = r2_score(ytest, pred)

print('MSE:',mse)
print('MAE:',mae)
print('R2_score:',r2)
# Out:
# MSE: 8627366.23032143
# MAE: 2363.471433382666
# R2_score: 0.5956620253860541
